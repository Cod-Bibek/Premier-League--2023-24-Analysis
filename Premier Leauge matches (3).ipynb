# %%
'''

    Questions
    1. How XG and goals related for each team.
    2. Does kick off time impact goals and result for any team.
    3. Does Referee has any influence in result and any team.
    4. Does possession impact the teams result. and much more during an analysis.

'''
# Out:
# '\n\n    Questions\n    1. How XG and goals related for each team.\n    2. Does kick off time impact goals and result for any team.\n    3. Does Referee has any influence in result and any team.\n    4. Does possession impact the teams result. and much more during an analysis.\n\n'

# %%
#Premier Leauge Matches 2023-2024 and its analyis. Thanks to keegle for dataset

# %%
#Importing required libraries
import pandas as pd
import numpy as np
import datetime as dt

# %%
#loading dataset 
prem_df = pd.read_csv(r'C:\Users\Bibek.Parajuli\OneDrive - Education Centre of Australia\Desktop\Premier Leauge 2023-2024\matches.csv')

# %%
prem_df.shape
# Out:
# (760, 28)

# %%
prem_df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Time', 'Comp', 'Round', 'Day', 'Venue', 'Result',
#        'GF', 'GA', 'Opponent', 'xG', 'xGA', 'Poss', 'Attendance', 'Captain',
#        'Formation', 'Referee', 'Match Report', 'Notes', 'Sh', 'SoT', 'Dist',
#        'FK', 'PK', 'PKatt', 'Season', 'Team'],
#       dtype='object')

# %%
prem_df.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0        Date   Time            Comp         Round  Day Venue  \
# 0             1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away
# 1             3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home
# 2             4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away
# 3             5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home
# 4             6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away
# ..          ...         ...    ...             ...           ...  ...   ...
# 755          36  2024-04-24  20:00  Premier League  Matchweek 29  Wed  Away
# 756          37  2024-04-27  15:00  Premier League  Matchweek 35  Sat  Away
# 757          38  2024-05-04  15:00  Premier League  Matchweek 36  Sat  Home
# 758          39  2024-05-11  15:00  Premier League  Matchweek 37  Sat  Away
# 759          40  2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home
#
# ...

# %%
prem_df.head(10)
# Out:
#    Unnamed: 0        Date   Time            Comp         Round  Day Venue  \
# 0           1  2023-08-11  20:00  Premier League   Matchweek 1  Fri  Away
# 1           3  2023-08-19  20:00  Premier League   Matchweek 2  Sat  Home
# 2           4  2023-08-27  14:00  Premier League   Matchweek 3  Sun  Away
# 3           5  2023-09-02  15:00  Premier League   Matchweek 4  Sat  Home
# 4           6  2023-09-16  15:00  Premier League   Matchweek 5  Sat  Away
# 5           8  2023-09-23  15:00  Premier League   Matchweek 6  Sat  Home
# 6          10  2023-09-30  15:00  Premier League   Matchweek 7  Sat  Away
# 7          12  2023-10-08  16:30  Premier League   Matchweek 8  Sun  Away
# 8          13  2023-10-21  15:00  Premier League   Matchweek 9  Sat  Home
# 9          15  2023-10-29  15:30  Premier League  Matchweek 10  Sun  Away
#
#   Result  GF  GA  ...  Match Report  Notes    Sh   SoT  Dist   FK PK PKatt  \
# 0      W   3   0  ...  Match Report    NaN  17.0   8.0  13.9  0.0  0     0
# ...

# %%
prem_df["Match Report"].nunique()
# Out:
# 1

# %%
#Deleting 'Match Report' column
prem_df.drop(columns = "Match Report",inplace = True)

# %%
prem_df.tail(10)
# Out:
#      Unnamed: 0        Date   Time            Comp         Round  Day Venue  \
# 750          31  2024-03-30  15:00  Premier League  Matchweek 30  Sat  Home
# 751          32  2024-04-04  19:30  Premier League  Matchweek 31  Thu  Away
# 752          33  2024-04-07  17:30  Premier League  Matchweek 32  Sun  Home
# 753          34  2024-04-13  15:00  Premier League  Matchweek 33  Sat  Away
# 754          35  2024-04-20  15:00  Premier League  Matchweek 34  Sat  Home
# 755          36  2024-04-24  20:00  Premier League  Matchweek 29  Wed  Away
# 756          37  2024-04-27  15:00  Premier League  Matchweek 35  Sat  Away
# 757          38  2024-05-04  15:00  Premier League  Matchweek 36  Sat  Home
# 758          39  2024-05-11  15:00  Premier League  Matchweek 37  Sat  Away
# 759          40  2024-05-19  16:00  Premier League  Matchweek 38  Sun  Home
#
#     Result  GF  GA  ...            Referee  Notes    Sh   SoT  Dist   FK PK  \
# ...

# %%
prem_df['Notes'].nunique()
# Out:
# 0

# %%
prem_df['Comp'].nunique()
# Out:
# 1

# %%
prem_df.drop(columns = ['Notes','Comp'],inplace= True)

# %%
prem_df.tail(10)
# Out:
#      Unnamed: 0        Date   Time         Round  Day Venue Result  GF  GA  \
# 750          31  2024-03-30  15:00  Matchweek 30  Sat  Home      D   3   3
# 751          32  2024-04-04  19:30  Matchweek 31  Thu  Away      L   1   3
# 752          33  2024-04-07  17:30  Matchweek 32  Sun  Home      D   2   2
# 753          34  2024-04-13  15:00  Matchweek 33  Sat  Away      L   0   2
# 754          35  2024-04-20  15:00  Matchweek 34  Sat  Home      L   1   4
# 755          36  2024-04-24  20:00  Matchweek 29  Wed  Away      L   2   4
# 756          37  2024-04-27  15:00  Matchweek 35  Sat  Away      L   1   5
# 757          38  2024-05-04  15:00  Matchweek 36  Sat  Home      L   1   3
# 758          39  2024-05-11  15:00  Matchweek 37  Sat  Away      L   0   1
# 759          40  2024-05-19  16:00  Matchweek 38  Sun  Home      L   0   3
#
#             Opponent  ...  Formation            Referee    Sh   SoT  Dist  \
# ...

# %%
prem_df.drop(columns = ['Season'],inplace = True)

# %%
prem_df.head(10)
# Out:
#    Unnamed: 0        Date   Time         Round  Day Venue Result  GF  GA  \
# 0           1  2023-08-11  20:00   Matchweek 1  Fri  Away      W   3   0
# 1           3  2023-08-19  20:00   Matchweek 2  Sat  Home      W   1   0
# 2           4  2023-08-27  14:00   Matchweek 3  Sun  Away      W   2   1
# 3           5  2023-09-02  15:00   Matchweek 4  Sat  Home      W   5   1
# 4           6  2023-09-16  15:00   Matchweek 5  Sat  Away      W   3   1
# 5           8  2023-09-23  15:00   Matchweek 6  Sat  Home      W   2   0
# 6          10  2023-09-30  15:00   Matchweek 7  Sat  Away      L   1   2
# 7          12  2023-10-08  16:30   Matchweek 8  Sun  Away      L   0   1
# 8          13  2023-10-21  15:00   Matchweek 9  Sat  Home      W   2   1
# 9          15  2023-10-29  15:30  Matchweek 10  Sun  Away      W   3   0
#
#           Opponent  ...          Captain  Formation         Referee    Sh  \
# 0          Burnley  ...  Kevin De Bruyne    4-2-3-1    Craig Pawson  17.0
# ...

# %%
prem_df[["Unnamed: 0","Team"]].head(50)
# Out:
#     Unnamed: 0            Team
# 0            1  ManchesterCity
# 1            3  ManchesterCity
# 2            4  ManchesterCity
# 3            5  ManchesterCity
# 4            6  ManchesterCity
# 5            8  ManchesterCity
# 6           10  ManchesterCity
# 7           12  ManchesterCity
# 8           13  ManchesterCity
# 9           15  ManchesterCity
# 10          16  ManchesterCity
# 11          18  ManchesterCity
# 12          19  ManchesterCity
# 13          21  ManchesterCity
# 14          22  ManchesterCity
# 15          23  ManchesterCity
# 16          25  ManchesterCity
# 17          26  ManchesterCity
# 18          27  ManchesterCity
# 19          29  ManchesterCity
# 20          31  ManchesterCity
# 21          32  ManchesterCity
# 22          33  ManchesterCity
# 23          35  ManchesterCity
# 24          36  ManchesterCity
# 25          37  ManchesterCity
# 26          39  ManchesterCity
# 27          41  ManchesterCity
# 28          43  ManchesterCity
# ...

# %%
prem_df.head(10)
# Out:
#    Unnamed: 0        Date   Time         Round  Day Venue Result  GF  GA  \
# 0           1  2023-08-11  20:00   Matchweek 1  Fri  Away      W   3   0
# 1           3  2023-08-19  20:00   Matchweek 2  Sat  Home      W   1   0
# 2           4  2023-08-27  14:00   Matchweek 3  Sun  Away      W   2   1
# 3           5  2023-09-02  15:00   Matchweek 4  Sat  Home      W   5   1
# 4           6  2023-09-16  15:00   Matchweek 5  Sat  Away      W   3   1
# 5           8  2023-09-23  15:00   Matchweek 6  Sat  Home      W   2   0
# 6          10  2023-09-30  15:00   Matchweek 7  Sat  Away      L   1   2
# 7          12  2023-10-08  16:30   Matchweek 8  Sun  Away      L   0   1
# 8          13  2023-10-21  15:00   Matchweek 9  Sat  Home      W   2   1
# 9          15  2023-10-29  15:30  Matchweek 10  Sun  Away      W   3   0
#
#           Opponent  ...          Captain  Formation         Referee    Sh  \
# 0          Burnley  ...  Kevin De Bruyne    4-2-3-1    Craig Pawson  17.0
# ...

# %%
(prem_df["Round"].isna()).nunique()
# Out:
# 1

# %%
# Split the string and convert the last part to integer
prem_df['Matchweek'] = prem_df['Round'].str.split().str[-1].astype(int)

# %%
prem_df.head(50)
# Out:
#     Unnamed: 0        Date   Time         Round  Day Venue Result  GF  GA  \
# 0            1  2023-08-11  20:00   Matchweek 1  Fri  Away      W   3   0
# 1            3  2023-08-19  20:00   Matchweek 2  Sat  Home      W   1   0
# 2            4  2023-08-27  14:00   Matchweek 3  Sun  Away      W   2   1
# 3            5  2023-09-02  15:00   Matchweek 4  Sat  Home      W   5   1
# 4            6  2023-09-16  15:00   Matchweek 5  Sat  Away      W   3   1
# 5            8  2023-09-23  15:00   Matchweek 6  Sat  Home      W   2   0
# 6           10  2023-09-30  15:00   Matchweek 7  Sat  Away      L   1   2
# 7           12  2023-10-08  16:30   Matchweek 8  Sun  Away      L   0   1
# 8           13  2023-10-21  15:00   Matchweek 9  Sat  Home      W   2   1
# 9           15  2023-10-29  15:30  Matchweek 10  Sun  Away      W   3   0
# 10          16  2023-11-04  15:00  Matchweek 11  Sat  Home      W   6   1
# 11          18  2023-11-12  16:30  Matchweek 12  Sun  Away      D   4   4
# ...

# %%
prem_df.drop(columns = "Unnamed: 0",inplace = True)

# %%
prem_df.head(50)
# Out:
#           Date   Time         Round  Day Venue Result  GF  GA  \
# 0   2023-08-11  20:00   Matchweek 1  Fri  Away      W   3   0
# 1   2023-08-19  20:00   Matchweek 2  Sat  Home      W   1   0
# 2   2023-08-27  14:00   Matchweek 3  Sun  Away      W   2   1
# 3   2023-09-02  15:00   Matchweek 4  Sat  Home      W   5   1
# 4   2023-09-16  15:00   Matchweek 5  Sat  Away      W   3   1
# 5   2023-09-23  15:00   Matchweek 6  Sat  Home      W   2   0
# 6   2023-09-30  15:00   Matchweek 7  Sat  Away      L   1   2
# 7   2023-10-08  16:30   Matchweek 8  Sun  Away      L   0   1
# 8   2023-10-21  15:00   Matchweek 9  Sat  Home      W   2   1
# 9   2023-10-29  15:30  Matchweek 10  Sun  Away      W   3   0
# 10  2023-11-04  15:00  Matchweek 11  Sat  Home      W   6   1
# 11  2023-11-12  16:30  Matchweek 12  Sun  Away      D   4   4
# 12  2023-11-25  12:30  Matchweek 13  Sat  Home      D   1   1
# 13  2023-12-03  16:30  Matchweek 14  Sun  Home      D   3   3
# ...

# %%
# Define the column to move to the front
column_to_front = 'Matchweek'

# Create the new column order with 'Matchweek' at the front
new_column_order = [column_to_front] + [col for col in prem_df.columns if col != column_to_front]

# Reorder the DataFrame using .reindex()
prem_df = prem_df.reindex(columns=new_column_order)

# %%
prem_df.head(10)
# Out:
#    Matchweek        Date   Time         Round  Day Venue Result  GF  GA  \
# 0          1  2023-08-11  20:00   Matchweek 1  Fri  Away      W   3   0
# 1          2  2023-08-19  20:00   Matchweek 2  Sat  Home      W   1   0
# 2          3  2023-08-27  14:00   Matchweek 3  Sun  Away      W   2   1
# 3          4  2023-09-02  15:00   Matchweek 4  Sat  Home      W   5   1
# 4          5  2023-09-16  15:00   Matchweek 5  Sat  Away      W   3   1
# 5          6  2023-09-23  15:00   Matchweek 6  Sat  Home      W   2   0
# 6          7  2023-09-30  15:00   Matchweek 7  Sat  Away      L   1   2
# 7          8  2023-10-08  16:30   Matchweek 8  Sun  Away      L   0   1
# 8          9  2023-10-21  15:00   Matchweek 9  Sat  Home      W   2   1
# 9         10  2023-10-29  15:30  Matchweek 10  Sun  Away      W   3   0
#
#           Opponent  ...          Captain  Formation         Referee    Sh  \
# 0          Burnley  ...  Kevin De Bruyne    4-2-3-1    Craig Pawson  17.0
# ...

# %%
prem_df["Team"].unique()
# Out:
# array(['ManchesterCity', 'Arsenal', 'Liverpool', 'AstonVilla',
#        'TottenhamHotspur', 'Chelsea', 'NewcastleUnited',
#        'ManchesterUnited', 'WestHamUnited', 'CrystalPalace',
#        'BrightonandHoveAlbion', 'Bournemouth', 'Fulham',
#        'WolverhamptonWanderers', 'Everton', 'Brentford',
#        'NottinghamForest', 'LutonTown', 'Burnley', 'SheffieldUnited'],
#       dtype=object)

# %%
prem_df["Opponent"].unique()
# Out:
# array(['Burnley', 'Newcastle Utd', 'Sheffield Utd', 'Fulham', 'West Ham',
#        "Nott'ham Forest", 'Wolves', 'Arsenal', 'Brighton',
#        'Manchester Utd', 'Bournemouth', 'Chelsea', 'Liverpool',
#        'Tottenham', 'Aston Villa', 'Luton Town', 'Crystal Palace',
#        'Everton', 'Brentford', 'Manchester City'], dtype=object)

# %%
#Define the mapping dictionary
abbr_team = {
    'ManchesterCity': 'MCI',
    'Arsenal': 'ARS',
    'Liverpool': 'LIV',
    'AstonVilla': 'AVL',
    'TottenhamHotspur': 'TOT',
    'Chelsea': 'CHE',
    'NewcastleUnited': 'NEW',
    'ManchesterUnited': 'MUN',
    'WestHamUnited': 'WHU',
    'CrystalPalace': 'CRY',
    'BrightonandHoveAlbion': 'BHA',
    'Bournemouth': 'BOU',
    'Fulham': 'FUL',
    'WolverhamptonWanderers': 'WOL',
    'Everton': 'EVE',
    'Brentford': 'BRE',
    'NottinghamForest': 'NFO',
    'LutonTown': 'LUT',
    'Burnley': 'BUR',
    'SheffieldUnited': 'SHU'
}
abbr_opp = {
                 'Burnley':'BUR',
                 'Newcastle Utd':'NEW',
                 'Sheffield Utd':'SHU',
                 'Fulham':'FUL',
                 'West Ham':'WHU',
                 "Nott'ham Forest":'NFO',
                 'Wolves':'WOL',
                 'Arsenal':'ARS',
                 'Brighton':'BHA',
                 'Manchester Utd':'MUN',
                 'Bournemouth':'BOU',
                 'Chelsea':'CHE',
                 'Liverpool':'LIV',
                 'Tottenham':'TOT',
                 'Aston Villa':'AVL', 
                 'Luton Town':'LUT',
                 'Crystal Palace':'CRY',
                 'Everton':'EVE',
                 'Brentford':'BRE',
                 'Manchester City':'MCI'
                }

# %%
prem_df.head(10)
# Out:
#    Matchweek        Date   Time         Round  Day Venue Result  GF  GA  \
# 0          1  2023-08-11  20:00   Matchweek 1  Fri  Away      W   3   0
# 1          2  2023-08-19  20:00   Matchweek 2  Sat  Home      W   1   0
# 2          3  2023-08-27  14:00   Matchweek 3  Sun  Away      W   2   1
# 3          4  2023-09-02  15:00   Matchweek 4  Sat  Home      W   5   1
# 4          5  2023-09-16  15:00   Matchweek 5  Sat  Away      W   3   1
# 5          6  2023-09-23  15:00   Matchweek 6  Sat  Home      W   2   0
# 6          7  2023-09-30  15:00   Matchweek 7  Sat  Away      L   1   2
# 7          8  2023-10-08  16:30   Matchweek 8  Sun  Away      L   0   1
# 8          9  2023-10-21  15:00   Matchweek 9  Sat  Home      W   2   1
# 9         10  2023-10-29  15:30  Matchweek 10  Sun  Away      W   3   0
#
#           Opponent  ...          Captain  Formation         Referee    Sh  \
# 0          Burnley  ...  Kevin De Bruyne    4-2-3-1    Craig Pawson  17.0
# ...

# %%
#Map the abbreviations for 'Opponent'
prem_df['Opponent_Abbr'] = prem_df['Opponent'].map(abbr_opp).fillna('UNKNOWN')

#Replace the 'Opponent' column with 'Opponent_Abbr'
prem_df['Opponent'] = prem_df['Opponent_Abbr']

#Drop the 'Opponent_abbr" column
prem_df.drop(columns='Opponent_Abbr',inplace = True)

# %%
prem_df.head(10)
# Out:
#    Matchweek        Date   Time         Round  Day Venue Result  GF  GA  \
# 0          1  2023-08-11  20:00   Matchweek 1  Fri  Away      W   3   0
# 1          2  2023-08-19  20:00   Matchweek 2  Sat  Home      W   1   0
# 2          3  2023-08-27  14:00   Matchweek 3  Sun  Away      W   2   1
# 3          4  2023-09-02  15:00   Matchweek 4  Sat  Home      W   5   1
# 4          5  2023-09-16  15:00   Matchweek 5  Sat  Away      W   3   1
# 5          6  2023-09-23  15:00   Matchweek 6  Sat  Home      W   2   0
# 6          7  2023-09-30  15:00   Matchweek 7  Sat  Away      L   1   2
# 7          8  2023-10-08  16:30   Matchweek 8  Sun  Away      L   0   1
# 8          9  2023-10-21  15:00   Matchweek 9  Sat  Home      W   2   1
# 9         10  2023-10-29  15:30  Matchweek 10  Sun  Away      W   3   0
#
#   Opponent  ...          Captain  Formation         Referee    Sh   SoT  Dist  \
# 0      BUR  ...  Kevin De Bruyne    4-2-3-1    Craig Pawson  17.0   8.0  13.9
# ...

# %%
prem_df['Opponent'].unique()
# Out:
# array(['BUR', 'NEW', 'SHU', 'FUL', 'WHU', 'NFO', 'WOL', 'ARS', 'BHA',
#        'MUN', 'BOU', 'CHE', 'LIV', 'TOT', 'AVL', 'LUT', 'CRY', 'EVE',
#        'BRE', 'MCI'], dtype=object)

# %%
#Map the abbreviations for 'Team'
prem_df['Team_Abbr'] = prem_df['Team'].map(abbr_team).fillna('UNKNOWN')

#Replace the 'Opponent' column with 'Opponent_Abbr'
prem_df['Team'] = prem_df['Team_Abbr']

#Drop the 'Opponent_abbr" column
prem_df.drop(columns='Team_Abbr',inplace = True)

# %%
prem_df['Team'].unique()
# Out:
# array(['MCI', 'ARS', 'LIV', 'AVL', 'TOT', 'CHE', 'NEW', 'MUN', 'WHU',
#        'CRY', 'BHA', 'BOU', 'FUL', 'WOL', 'EVE', 'BRE', 'NFO', 'LUT',
#        'BUR', 'SHU'], dtype=object)

# %%
#Apply the Concat function to each row
prem_df['Match_ID'] = prem_df['Team'] +"_VS_"+ prem_df['Opponent']

# %%
prem_df.head(10)
# Out:
#    Matchweek        Date   Time         Round  Day Venue Result  GF  GA  \
# 0          1  2023-08-11  20:00   Matchweek 1  Fri  Away      W   3   0
# 1          2  2023-08-19  20:00   Matchweek 2  Sat  Home      W   1   0
# 2          3  2023-08-27  14:00   Matchweek 3  Sun  Away      W   2   1
# 3          4  2023-09-02  15:00   Matchweek 4  Sat  Home      W   5   1
# 4          5  2023-09-16  15:00   Matchweek 5  Sat  Away      W   3   1
# 5          6  2023-09-23  15:00   Matchweek 6  Sat  Home      W   2   0
# 6          7  2023-09-30  15:00   Matchweek 7  Sat  Away      L   1   2
# 7          8  2023-10-08  16:30   Matchweek 8  Sun  Away      L   0   1
# 8          9  2023-10-21  15:00   Matchweek 9  Sat  Home      W   2   1
# 9         10  2023-10-29  15:30  Matchweek 10  Sun  Away      W   3   0
#
#   Opponent  ...  Formation         Referee    Sh   SoT  Dist   FK PK  PKatt  \
# 0      BUR  ...    4-2-3-1    Craig Pawson  17.0   8.0  13.9  0.0  0      0
# ...

# %%
# Define the column to move to the front
column_to_front = 'Match_ID'

# Create the new column order with 'Match_ID' at the front
new_column_order = [column_to_front] + [col for col in prem_df.columns if col != column_to_front]

# Reorder the DataFrame using .reindex()
prem_df = prem_df.reindex(columns=new_column_order)

# %%
prem_df.head(10)
# Out:
#      Match_ID  Matchweek        Date   Time         Round  Day Venue Result  \
# 0  MCI_VS_BUR          1  2023-08-11  20:00   Matchweek 1  Fri  Away      W
# 1  MCI_VS_NEW          2  2023-08-19  20:00   Matchweek 2  Sat  Home      W
# 2  MCI_VS_SHU          3  2023-08-27  14:00   Matchweek 3  Sun  Away      W
# 3  MCI_VS_FUL          4  2023-09-02  15:00   Matchweek 4  Sat  Home      W
# 4  MCI_VS_WHU          5  2023-09-16  15:00   Matchweek 5  Sat  Away      W
# 5  MCI_VS_NFO          6  2023-09-23  15:00   Matchweek 6  Sat  Home      W
# 6  MCI_VS_WOL          7  2023-09-30  15:00   Matchweek 7  Sat  Away      L
# 7  MCI_VS_ARS          8  2023-10-08  16:30   Matchweek 8  Sun  Away      L
# 8  MCI_VS_BHA          9  2023-10-21  15:00   Matchweek 9  Sat  Home      W
# 9  MCI_VS_MUN         10  2023-10-29  15:30  Matchweek 10  Sun  Away      W
#
#    GF  GA  ...          Captain  Formation         Referee    Sh   SoT  Dist  \
# ...

# %%
#Drop 'Round' column' as we have seperate column for match week
prem_df.drop(columns = ['Round'], inplace= True)

# %%
prem_df.head()
# Out:
#      Match_ID  Matchweek        Date   Time  Day Venue Result  GF  GA  \
# 0  MCI_VS_BUR          1  2023-08-11  20:00  Fri  Away      W   3   0
# 1  MCI_VS_NEW          2  2023-08-19  20:00  Sat  Home      W   1   0
# 2  MCI_VS_SHU          3  2023-08-27  14:00  Sun  Away      W   2   1
# 3  MCI_VS_FUL          4  2023-09-02  15:00  Sat  Home      W   5   1
# 4  MCI_VS_WHU          5  2023-09-16  15:00  Sat  Away      W   3   1
#
#   Opponent  ...          Captain  Formation         Referee    Sh   SoT  Dist  \
# 0      BUR  ...  Kevin De Bruyne    4-2-3-1    Craig Pawson  17.0   8.0  13.9
# 1      NEW  ...      Kyle Walker    4-2-3-1    Robert Jones  14.0   4.0  17.9
# 2      SHU  ...      Kyle Walker    4-2-3-1  Jarred Gillett  29.0   9.0  17.3
# 3      FUL  ...      Kyle Walker    4-2-3-1  Michael Oliver   6.0   4.0  14.8
# 4      WHU  ...      Kyle Walker    4-2-3-1     Andy Madley  29.0  13.0  16.4
#
#     FK  PK  PKatt  Team
# 0  0.0   0      0   MCI
# 1  0.0   0      0   MCI
# ...

# %%
prem_df.head(10)
# Out:
#      Match_ID  Matchweek        Date   Time  Day Venue Result  GF  GA  \
# 0  MCI_VS_BUR          1  2023-08-11  20:00  Fri  Away      W   3   0
# 1  MCI_VS_NEW          2  2023-08-19  20:00  Sat  Home      W   1   0
# 2  MCI_VS_SHU          3  2023-08-27  14:00  Sun  Away      W   2   1
# 3  MCI_VS_FUL          4  2023-09-02  15:00  Sat  Home      W   5   1
# 4  MCI_VS_WHU          5  2023-09-16  15:00  Sat  Away      W   3   1
# 5  MCI_VS_NFO          6  2023-09-23  15:00  Sat  Home      W   2   0
# 6  MCI_VS_WOL          7  2023-09-30  15:00  Sat  Away      L   1   2
# 7  MCI_VS_ARS          8  2023-10-08  16:30  Sun  Away      L   0   1
# 8  MCI_VS_BHA          9  2023-10-21  15:00  Sat  Home      W   2   1
# 9  MCI_VS_MUN         10  2023-10-29  15:30  Sun  Away      W   3   0
#
#   Opponent  ...          Captain  Formation         Referee    Sh   SoT  Dist  \
# 0      BUR  ...  Kevin De Bruyne    4-2-3-1    Craig Pawson  17.0   8.0  13.9
# ...

# %%
prem_df.tail(10)
# Out:
#        Match_ID  Matchweek        Date   Time  Day Venue Result  GF  GA  \
# 750  SHU_VS_FUL         30  2024-03-30  15:00  Sat  Home      D   3   3
# 751  SHU_VS_LIV         31  2024-04-04  19:30  Thu  Away      L   1   3
# 752  SHU_VS_CHE         32  2024-04-07  17:30  Sun  Home      D   2   2
# 753  SHU_VS_BRE         33  2024-04-13  15:00  Sat  Away      L   0   2
# 754  SHU_VS_BUR         34  2024-04-20  15:00  Sat  Home      L   1   4
# 755  SHU_VS_MUN         29  2024-04-24  20:00  Wed  Away      L   2   4
# 756  SHU_VS_NEW         35  2024-04-27  15:00  Sat  Away      L   1   5
# 757  SHU_VS_NFO         36  2024-05-04  15:00  Sat  Home      L   1   3
# 758  SHU_VS_EVE         37  2024-05-11  15:00  Sat  Away      L   0   1
# 759  SHU_VS_TOT         38  2024-05-19  16:00  Sun  Home      L   0   3
#
#     Opponent  ...           Captain  Formation            Referee    Sh   SoT  \
# 750      FUL  ...     Jack Robinson      3-5-2       Tim Robinson   8.0   4.0
# ...

# %%
prem_df["Team"].unique()
# Out:
# array(['MCI', 'ARS', 'LIV', 'AVL', 'TOT', 'CHE', 'NEW', 'MUN', 'WHU',
#        'CRY', 'BHA', 'BOU', 'FUL', 'WOL', 'EVE', 'BRE', 'NFO', 'LUT',
#        'BUR', 'SHU'], dtype=object)

# %%
# Define the column to move to the front
column_to_front = 'Team'

# Create the new column order with 'Team' at the front
new_column_order = [column_to_front] + [col for col in prem_df.columns if col != column_to_front]

# Reorder the DataFrame using .reindex()
prem_df = prem_df.reindex(columns=new_column_order)

# %%
# Define the column to move to the front
column_to_front = 'Match_ID'

# Create the new column order with 'Match_ID' at the front
new_column_order = [column_to_front] + [col for col in prem_df.columns if col != column_to_front]

# Reorder the DataFrame using .reindex()
prem_df = prem_df.reindex(columns=new_column_order)

# %%
prem_df.head(10)
# Out:
#      Match_ID Team  Matchweek        Date   Time  Day Venue Result  GF  GA  \
# 0  MCI_VS_BUR  MCI          1  2023-08-11  20:00  Fri  Away      W   3   0
# 1  MCI_VS_NEW  MCI          2  2023-08-19  20:00  Sat  Home      W   1   0
# 2  MCI_VS_SHU  MCI          3  2023-08-27  14:00  Sun  Away      W   2   1
# 3  MCI_VS_FUL  MCI          4  2023-09-02  15:00  Sat  Home      W   5   1
# 4  MCI_VS_WHU  MCI          5  2023-09-16  15:00  Sat  Away      W   3   1
# 5  MCI_VS_NFO  MCI          6  2023-09-23  15:00  Sat  Home      W   2   0
# 6  MCI_VS_WOL  MCI          7  2023-09-30  15:00  Sat  Away      L   1   2
# 7  MCI_VS_ARS  MCI          8  2023-10-08  16:30  Sun  Away      L   0   1
# 8  MCI_VS_BHA  MCI          9  2023-10-21  15:00  Sat  Home      W   2   1
# 9  MCI_VS_MUN  MCI         10  2023-10-29  15:30  Sun  Away      W   3   0
#
#    ... Attendance          Captain  Formation         Referee    Sh   SoT  \
# ...

# %%
prem_df.columns
# Out:
# Index(['Match_ID', 'Team', 'Matchweek', 'Date', 'Time', 'Day', 'Venue',
#        'Result', 'GF', 'GA', 'Opponent', 'xG', 'xGA', 'Poss', 'Attendance',
#        'Captain', 'Formation', 'Referee', 'Sh', 'SoT', 'Dist', 'FK', 'PK',
#        'PKatt'],
#       dtype='object')

# %%
#Reindexing columns in dataframe
new_column_order = ['Match_ID','Team','Opponent','Matchweek','Referee','Venue','Attendance','Formation','Captain','Date','Time','Day',
                    'Result','GF','GA','xG','xGA','Poss','Attendance','Sh','SoT','Dist','FK','PK','PKatt']
prem_df = prem_df[new_column_order]

# %%
prem_df.head(10)
# Out:
#      Match_ID Team Opponent  Matchweek         Referee Venue  Attendance  \
# 0  MCI_VS_BUR  MCI      BUR          1    Craig Pawson  Away     21572.0
# 1  MCI_VS_NEW  MCI      NEW          2    Robert Jones  Home     53419.0
# 2  MCI_VS_SHU  MCI      SHU          3  Jarred Gillett  Away     31336.0
# 3  MCI_VS_FUL  MCI      FUL          4  Michael Oliver  Home     52899.0
# 4  MCI_VS_WHU  MCI      WHU          5     Andy Madley  Away     62475.0
# 5  MCI_VS_NFO  MCI      NFO          6  Anthony Taylor  Home     53413.0
# 6  MCI_VS_WOL  MCI      WOL          7    Craig Pawson  Away     31415.0
# 7  MCI_VS_ARS  MCI      ARS          8  Michael Oliver  Away     60233.0
# 8  MCI_VS_BHA  MCI      BHA          9    Robert Jones  Home     53466.0
# 9  MCI_VS_MUN  MCI      MUN         10    Paul Tierney  Away     73502.0
#
#   Formation          Captain        Date  ...   xG  xGA  Poss  Attendance  \
# 0   4-2-3-1  Kevin De Bruyne  2023-08-11  ...  1.9  0.3  65.0     21572.0
# ...

# %%
#lets check which team has scored more and less that their expected goals.
df_xGs = prem_df.groupby('Team')[['xG','GF','xGA','GA']].sum()

df_xGs[df_xGs['xG'] > df_xGs['GF'] ]
# Out:
#         xG  GF   xGA   GA
# Team
# BHA   56.6  55  55.7   62
# BOU   56.0  54  58.1   67
# BRE   58.2  56  56.0   65
# EVE   53.5  40  55.3   51
# LIV   87.8  86  45.8   41
# NFO   50.0  49  53.2   67
# SHU   38.6  35  76.7  104

# %%
#NOTE: It is interesting to see that out of 20 teams, 7 teams have less than expected goals. Out of them if we put 5 as constraint ,EVERTON has scored way than XG by 13.
# which suggest that Everton has created good amount of chances but unable to scored from them. They need to work on finishing or get someone who has
# good finishing skills.
df_xGs[df_xGs['xG'] > (df_xGs['GF'] + 5 )]
# Out:
#         xG  GF   xGA  GA
# Team
# EVE   53.5  40  55.3  51

# %%
# lets check which team has conceded more than it expected:
df_xGs[df_xGs['xGA'] < df_xGs['GA']]
# Out:
#         xG  GF   xGA   GA
# Team
# ARS   76.3  91  27.8   29
# AVL   63.5  76  60.0   61
# BHA   56.6  55  55.7   62
# BOU   56.0  54  58.1   67
# BRE   58.2  56  56.0   65
# BUR   40.6  41  70.0   78
# CHE   74.5  77  58.3   63
# CRY   48.7  57  52.2   58
# LUT   42.3  52  77.8   85
# NEW   76.1  85  61.5   62
# NFO   50.0  49  53.2   67
# SHU   38.6  35  76.7  104
# WHU   52.5  60  71.3   74

# %%
df_xGs[(df_xGs['xGA'] + 5 )< df_xGs['GA'] ]
# Out:
#         xG  GF   xGA   GA
# Team
# BHA   56.6  55  55.7   62
# BOU   56.0  54  58.1   67
# BRE   58.2  56  56.0   65
# BUR   40.6  41  70.0   78
# CRY   48.7  57  52.2   58
# LUT   42.3  52  77.8   85
# NFO   50.0  49  53.2   67
# SHU   38.6  35  76.7  104

# %%
prem_df.columns
# Out:
# Index(['Match_ID', 'Team', 'Opponent', 'Matchweek', 'Referee', 'Venue',
#        'Attendance', 'Formation', 'Captain', 'Date', 'Time', 'Day', 'Result',
#        'GF', 'GA', 'xG', 'xGA', 'Poss', 'Attendance', 'Sh', 'SoT', 'Dist',
#        'FK', 'PK', 'PKatt'],
#       dtype='object')

# %%
prem_df[prem_df['Referee'] == "Michael Oliver"]
# Out:
#        Match_ID Team Opponent  Matchweek         Referee Venue  Attendance  \
# 3    MCI_VS_FUL  MCI      FUL          4  Michael Oliver  Home     52899.0
# 7    MCI_VS_ARS  MCI      ARS          8  Michael Oliver  Away     60233.0
# 27   MCI_VS_LIV  MCI      LIV         28  Michael Oliver  Away     59947.0
# 38   ARS_VS_NFO  ARS      NFO          1  Michael Oliver  Home     59984.0
# 45   ARS_VS_MCI  ARS      MCI          8  Michael Oliver  Home     60233.0
# 49   ARS_VS_BUR  ARS      BUR         12  Michael Oliver  Home     60232.0
# 56   ARS_VS_WHU  ARS      WHU         19  Michael Oliver  Home     60261.0
# 72   ARS_VS_TOT  ARS      TOT         35  Michael Oliver  Away     61554.0
# 75   ARS_VS_EVE  ARS      EVE         38  Michael Oliver  Home     60312.0
# 80   LIV_VS_WOL  LIV      WOL          5  Michael Oliver  Away     31257.0
# 92   LIV_VS_MUN  LIV      MUN         17  Michael Oliver  Home     57158.0
# ...

# %%
prem_df.head()
# Out:
#      Match_ID Team Opponent  Matchweek         Referee Venue  Attendance  \
# 0  MCI_VS_BUR  MCI      BUR          1    Craig Pawson  Away     21572.0
# 1  MCI_VS_NEW  MCI      NEW          2    Robert Jones  Home     53419.0
# 2  MCI_VS_SHU  MCI      SHU          3  Jarred Gillett  Away     31336.0
# 3  MCI_VS_FUL  MCI      FUL          4  Michael Oliver  Home     52899.0
# 4  MCI_VS_WHU  MCI      WHU          5     Andy Madley  Away     62475.0
#
#   Formation          Captain        Date  ...   xG  xGA  Poss  Attendance  \
# 0   4-2-3-1  Kevin De Bruyne  2023-08-11  ...  1.9  0.3  65.0     21572.0
# 1   4-2-3-1      Kyle Walker  2023-08-19  ...  1.0  0.3  59.0     53419.0
# 2   4-2-3-1      Kyle Walker  2023-08-27  ...  3.5  0.7  79.0     31336.0
# 3   4-2-3-1      Kyle Walker  2023-09-02  ...  2.2  1.4  68.0     52899.0
# 4   4-2-3-1      Kyle Walker  2023-09-16  ...  3.6  0.9  68.0     62475.0
#
#      Sh   SoT  Dist   FK  PK  PKatt
# 0  17.0   8.0  13.9  0.0   0      0
# ...

# %%
#Creating new data frame for data anlaysis of manchester united preformances
mun_df = prem_df[prem_df['Team'] == 'MUN']

# %%
mun_df
# Out:
#        Match_ID Team Opponent  Matchweek            Referee Venue  Attendance  \
# 266  MUN_VS_WOL  MUN      WOL          1       Simon Hooper  Home     73358.0
# 267  MUN_VS_TOT  MUN      TOT          2     Michael Oliver  Away     61910.0
# 268  MUN_VS_NFO  MUN      NFO          3     Stuart Attwell  Home     73595.0
# 269  MUN_VS_ARS  MUN      ARS          4     Anthony Taylor  Away     60192.0
# 270  MUN_VS_BHA  MUN      BHA          5     Jarred Gillett  Home     73592.0
# 271  MUN_VS_BUR  MUN      BUR          6    Tony Harrington  Away     21593.0
# 272  MUN_VS_CRY  MUN      CRY          7     Chris Kavanagh  Home     73428.0
# 273  MUN_VS_BRE  MUN      BRE          8        Andy Madley  Home     73453.0
# 274  MUN_VS_SHU  MUN      SHU          9     Michael Oliver  Away     31543.0
# 275  MUN_VS_MCI  MUN      MCI         10       Paul Tierney  Home     73502.0
# 276  MUN_VS_FUL  MUN      FUL         11        John Brooks  Away     24415.0
# ...

# %%
#Calculating average possession for 2023/24 season
mun_df['Poss'].mean().round(2)
# Out:
# 50.58

# %%
#Calulating average possesion for all team expect manchester united on 2023/24 season
prem_df.groupby('Team')['Poss'].mean().round(2).sort_values(ascending = False).reset_index()
# Out:
#    Team   Poss
# 0   MCI  65.21
# 1   TOT  61.58
# 2   LIV  61.26
# 3   BHA  59.84
# 4   CHE  58.61
# 5   ARS  58.18
# 6   AVL  53.11
# 7   NEW  52.21
# 8   FUL  50.61
# 9   MUN  50.58
# 10  WOL  48.87
# 11  BUR  47.37
# 12  BRE  45.16
# 13  BOU  44.39
# 14  LUT  42.37
# 15  CRY  42.29
# 16  WHU  41.11
# 17  EVE  40.84
# 18  NFO  40.58
# 19  SHU  35.84

# %%
prem_df.groupby('Team')['GF'].sum().sort_values(ascending = False ).reset_index()
# Out:
#    Team  GF
# 0   MCI  96
# 1   ARS  91
# 2   LIV  86
# 3   NEW  85
# 4   CHE  77
# 5   AVL  76
# 6   TOT  74
# 7   WHU  60
# 8   CRY  57
# 9   MUN  57
# 10  BRE  56
# 11  FUL  55
# 12  BHA  55
# 13  BOU  54
# 14  LUT  52
# 15  WOL  50
# 16  NFO  49
# 17  BUR  41
# 18  EVE  40
# 19  SHU  35

# %%
prem_df.groupby('Team')['GA'].sum().sort_values(ascending = True).reset_index()
# Out:
#    Team   GA
# 0   ARS   29
# 1   MCI   34
# 2   LIV   41
# 3   EVE   51
# 4   MUN   58
# 5   CRY   58
# 6   TOT   61
# 7   FUL   61
# 8   AVL   61
# 9   BHA   62
# 10  NEW   62
# 11  CHE   63
# 12  BRE   65
# 13  WOL   65
# 14  BOU   67
# 15  NFO   67
# 16  WHU   74
# 17  BUR   78
# 18  LUT   85
# 19  SHU  104

# %%
prem_df.columns
# Out:
# Index(['Match_ID', 'Team', 'Opponent', 'Matchweek', 'Referee', 'Venue',
#        'Attendance', 'Formation', 'Captain', 'Date', 'Time', 'Day', 'Result',
#        'GF', 'GA', 'xG', 'xGA', 'Poss', 'Attendance', 'Sh', 'SoT', 'Dist',
#        'FK', 'PK', 'PKatt'],
#       dtype='object')

# %%
pivot_table = pd.pivot_table(prem_df,index =['Team'] , values = ['xG','GF'],aggfunc = 'sum')

# %%
sorted_by_xG = pivot_table.sort_values(by = ['xG','GF'], ascending = False)
sorted_by_xG
# Out:
#       GF    xG
# Team
# LIV   86  87.8
# MCI   96  80.6
# ARS   91  76.3
# NEW   85  76.1
# CHE   77  74.5
# TOT   74  68.0
# AVL   76  63.5
# BRE   56  58.2
# MUN   57  56.6
# BHA   55  56.6
# BOU   54  56.0
# EVE   40  53.5
# WHU   60  52.5
# FUL   55  50.8
# NFO   49  50.0
# CRY   57  48.7
# WOL   50  47.0
# LUT   52  42.3
# BUR   41  40.6
# SHU   35  38.6

# %%
sorted_by_xG.sort_index()
# Out:
#       GF    xG
# Team
# ARS   91  76.3
# AVL   76  63.5
# BHA   55  56.6
# BOU   54  56.0
# BRE   56  58.2
# BUR   41  40.6
# CHE   77  74.5
# CRY   57  48.7
# EVE   40  53.5
# FUL   55  50.8
# LIV   86  87.8
# LUT   52  42.3
# MCI   96  80.6
# MUN   57  56.6
# NEW   85  76.1
# NFO   49  50.0
# SHU   35  38.6
# TOT   74  68.0
# WHU   60  52.5
# WOL   50  47.0

# %%
sorted_by_xG
# Out:
#       GF    xG
# Team
# LIV   86  87.8
# MCI   96  80.6
# ARS   91  76.3
# NEW   85  76.1
# CHE   77  74.5
# TOT   74  68.0
# AVL   76  63.5
# BRE   56  58.2
# MUN   57  56.6
# BHA   55  56.6
# BOU   54  56.0
# EVE   40  53.5
# WHU   60  52.5
# FUL   55  50.8
# NFO   49  50.0
# CRY   57  48.7
# WOL   50  47.0
# LUT   52  42.3
# BUR   41  40.6
# SHU   35  38.6

# %%
#Lets Check Correlation between XG and GF

# %%
correlation_xG_GF = sorted_by_xG['GF'].corr(sorted_by_xG['xG'])

# %%
correlation_xG_GF
# Out:
# 0.9262134194351244

# %%
prem_df
# Out:
#        Match_ID Team Opponent  Matchweek            Referee Venue  Attendance  \
# 0    MCI_VS_BUR  MCI      BUR          1       Craig Pawson  Away     21572.0
# 1    MCI_VS_NEW  MCI      NEW          2       Robert Jones  Home     53419.0
# 2    MCI_VS_SHU  MCI      SHU          3     Jarred Gillett  Away     31336.0
# 3    MCI_VS_FUL  MCI      FUL          4     Michael Oliver  Home     52899.0
# 4    MCI_VS_WHU  MCI      WHU          5        Andy Madley  Away     62475.0
# ..          ...  ...      ...        ...                ...   ...         ...
# 755  SHU_VS_MUN  SHU      MUN         29  Michael Salisbury  Away     73549.0
# 756  SHU_VS_NEW  SHU      NEW         35    Tony Harrington  Away     52196.0
# 757  SHU_VS_NFO  SHU      NFO         36     Chris Kavanagh  Home     28516.0
# 758  SHU_VS_EVE  SHU      EVE         37     Stuart Attwell  Away     39221.0
# 759  SHU_VS_TOT  SHU      TOT         38        Andy Madley  Home     29116.0
#
# ...

# %%
import os
# Specify the directory and file name using raw string
directory = r'C:\Users\Bibek.Parajuli\OneDrive - Education Centre of Australia\Desktop\Data Project\Cleaned Dataset'
file_name = 'Premier League Matches Dataset 2023-24 Season.csv'
file_path = os.path.join(directory, file_name)

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Save the DataFrame to a CSV file in the specified directory
prem_df.to_csv(file_path, index=False)

print(f"File saved to {file_path}")
# Out:
# File saved to C:\Users\Bibek.Parajuli\OneDrive - Education Centre of Australia\Desktop\Data Project\Cleaned Dataset\Premier League Matches Dataset 2023-24 Season.csv

# %%
def total_points(x):
    if x == "W":
        return 3
    elif x == "D":
        return 1
    else:
        return 0

prem_df['Points'] = prem_df['Result'].map(total_points)

# %%
prem_df['Points']
# Out:
# 0      3
# 1      3
# 2      3
# 3      3
# 4      3
#       ..
# 755    0
# 756    0
# 757    0
# 758    0
# 759    0
# Name: Points, Length: 760, dtype: int64

# %%
pivot_table = pd.pivot_table(data = prem_df, index = ['Team'], values = ['Points'], aggfunc = 'sum').sort_values(by = 'Points', ascending = False).reset_index()
pivot_table.index = range(1, len(pivot_table) + 1)

# %%
pivot_table
# Out:
#    Team  Points
# 1   MCI      91
# 2   ARS      89
# 3   LIV      82
# 4   AVL      68
# 5   TOT      66
# 6   CHE      63
# 7   NEW      60
# 8   MUN      60
# 9   WHU      52
# 10  CRY      49
# 11  BOU      48
# 12  EVE      48
# 13  BHA      48
# 14  FUL      47
# 15  WOL      46
# 16  BRE      39
# 17  NFO      36
# 18  LUT      26
# 19  BUR      24
# 20  SHU      16

# %%
prem_df
# Out:
#        Match_ID Team Opponent  Matchweek            Referee Venue Attendance  \
# 0    MCI_VS_BUR  MCI      BUR          1       Craig Pawson  Away    21572.0
# 1    MCI_VS_NEW  MCI      NEW          2       Robert Jones  Home    53419.0
# 2    MCI_VS_SHU  MCI      SHU          3     Jarred Gillett  Away    31336.0
# 3    MCI_VS_FUL  MCI      FUL          4     Michael Oliver  Home    52899.0
# 4    MCI_VS_WHU  MCI      WHU          5        Andy Madley  Away    62475.0
# ..          ...  ...      ...        ...                ...   ...        ...
# 755  SHU_VS_MUN  SHU      MUN         29  Michael Salisbury  Away    73549.0
# 756  SHU_VS_NEW  SHU      NEW         35    Tony Harrington  Away    52196.0
# 757  SHU_VS_NFO  SHU      NFO         36     Chris Kavanagh  Home    28516.0
# 758  SHU_VS_EVE  SHU      EVE         37     Stuart Attwell  Away    39221.0
# 759  SHU_VS_TOT  SHU      TOT         38        Andy Madley  Home    29116.0
#
# ...

# %%
pd.pivot_table(data = prem_df , index = 'Team', columns = 'Venue', values = 'Points', aggfunc = 'sum').sort_values(by = 'Home', ascending = False)
# Out:
# Venue  Away  Home
# Team
# LIV      34    48
# MCI      44    47
# ARS      42    47
# NEW      20    40
# AVL      28    40
# TOT      27    39
# CHE      26    37
# MUN      27    33
# BHA      18    30
# WHU      23    29
# FUL      18    29
# CRY      21    28
# EVE      20    28
# BOU      21    27
# WOL      19    27
# BRE      17    22
# NFO      16    20
# LUT      10    16
# SHU       6    10
# BUR      14    10

# %%
#Reading 2022-23 table from website
url_2022_23_table = 'https://fbref.com/en/comps/9/2022-2023/2022-2023-Premier-League-Stats'
table_2022_23 = pd.read_html(url_2022_23_table)
print(f"Number of tables found: {len(table_2022_23)}")
# Out:
# Number of tables found: 24

# %%
#Reading table 2022

# %%
prem_df["cumGoals"] = prem_df.groupby("Team")["GF"].cumsum()

# %%
prem_df[['Team','cumGoals']]
# Out:
#     Team  cumGoals
# 0    MCI         3
# 1    MCI         4
# 2    MCI         6
# 3    MCI        11
# 4    MCI        14
# ..   ...       ...
# 755  SHU        33
# 756  SHU        34
# 757  SHU        35
# 758  SHU        35
# 759  SHU        35
#
# [760 rows x 2 columns]

# %%
shot_table = prem_df.groupby('Team').agg({'Sh':'sum','SoT':'sum'})

# %%
shot_table["Shot Effeciency"] = (shot_table['SoT']/shot_table['Sh']).round(2)

# %%
shot_table
# Out:
#          Sh    SoT  Shot Effeciency
# Team
# ARS   647.0  209.0             0.32
# AVL   511.0  182.0             0.36
# BHA   555.0  198.0             0.36
# BOU   539.0  175.0             0.32
# BRE   470.0  159.0             0.34
# BUR   430.0  137.0             0.32
# CHE   537.0  194.0             0.36
# CRY   452.0  162.0             0.36
# EVE   504.0  152.0             0.30
# FUL   499.0  175.0             0.35
# LIV   781.0  263.0             0.34
# LUT   427.0  134.0             0.31
# MCI   683.0  264.0             0.39
# MUN   543.0  182.0             0.34
# NEW   542.0  196.0             0.36
# NFO   450.0  143.0             0.32
# SHU   360.0  117.0             0.32
# TOT   582.0  207.0             0.36
# WHU   445.0  146.0             0.33
# WOL   425.0  153.0             0.36

# %%
import os
# Specify the directory and file name using raw string
directory = r'C:\Users\Bibek.Parajuli\OneDrive - Education Centre of Australia\Desktop\Data Project\Cleaned Dataset'
file_name = 'shot_efficency 2023_24.csv'
file_path = os.path.join(directory, file_name)

# Create the directory if it doesn't exist
if not os.path.exists(directory):
    os.makedirs(directory)

# Save the DataFrame to a CSV file in the specified directory
shot_table.to_csv(file_path, index=True)

print(f"File saved to {file_path}")
# Out:
# File saved to C:\Users\Bibek.Parajuli\OneDrive - Education Centre of Australia\Desktop\Data Project\Cleaned Dataset\shot_efficency 2023_24.csv

# %%
prem_df
# Out:
#        Match_ID Team Opponent  Matchweek            Referee Venue Attendance  \
# 0    MCI_VS_BUR  MCI      BUR          1       Craig Pawson  Away    21572.0
# 1    MCI_VS_NEW  MCI      NEW          2       Robert Jones  Home    53419.0
# 2    MCI_VS_SHU  MCI      SHU          3     Jarred Gillett  Away    31336.0
# 3    MCI_VS_FUL  MCI      FUL          4     Michael Oliver  Home    52899.0
# 4    MCI_VS_WHU  MCI      WHU          5        Andy Madley  Away    62475.0
# ..          ...  ...      ...        ...                ...   ...        ...
# 755  SHU_VS_MUN  SHU      MUN         29  Michael Salisbury  Away    73549.0
# 756  SHU_VS_NEW  SHU      NEW         35    Tony Harrington  Away    52196.0
# 757  SHU_VS_NFO  SHU      NFO         36     Chris Kavanagh  Home    28516.0
# 758  SHU_VS_EVE  SHU      EVE         37     Stuart Attwell  Away    39221.0
# 759  SHU_VS_TOT  SHU      TOT         38        Andy Madley  Home    29116.0
#
# ...

# %%
prem_df
# Out:
#        Match_ID Team Opponent  Matchweek            Referee Venue Attendance  \
# 0    MCI_VS_BUR  MCI      BUR          1       Craig Pawson  Away    21572.0
# 1    MCI_VS_NEW  MCI      NEW          2       Robert Jones  Home    53419.0
# 2    MCI_VS_SHU  MCI      SHU          3     Jarred Gillett  Away    31336.0
# 3    MCI_VS_FUL  MCI      FUL          4     Michael Oliver  Home    52899.0
# 4    MCI_VS_WHU  MCI      WHU          5        Andy Madley  Away    62475.0
# ..          ...  ...      ...        ...                ...   ...        ...
# 755  SHU_VS_MUN  SHU      MUN         29  Michael Salisbury  Away    73549.0
# 756  SHU_VS_NEW  SHU      NEW         35    Tony Harrington  Away    52196.0
# 757  SHU_VS_NFO  SHU      NFO         36     Chris Kavanagh  Home    28516.0
# 758  SHU_VS_EVE  SHU      EVE         37     Stuart Attwell  Away    39221.0
# 759  SHU_VS_TOT  SHU      TOT         38        Andy Madley  Home    29116.0
#
# ...
